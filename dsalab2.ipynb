# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul31616/19_Codex_BnB24/blob/main/dsalab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

mtcars = pd.read_csv('mtcars.csv')

# %%
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
pd.crosstab(mtcars.gear,mtcars.cyl).plot(kind="bar")
# Out:
# <Axes: xlabel='gear'>

# %%
<Axes : xlabel='gear'>
# Out:
#   File "<ipython-input-10-3677f2724832>", line 1
#     <Axes : xlabel='gear'>
#     ^
# SyntaxError: invalid syntax

# %%
mtcars["gear"].value_counts()
mtcars.gear.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
plt.scatter(mtcars.mpg,mtcars.qsec)

# %%
plt.hist(mtcars['mpg'])
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtcars['mpg'],facecolor = "red",edgecolor = "blue",bins = 5)
# Out:
# (array([ 6., 12.,  8.,  2.,  4.]),
#  array([10.4, 15.1, 19.8, 24.5, 29.2, 33.9]),
#  <BarContainer object of 5 artists>)

# %%
plt.boxplot(mtcars['mpg'],vert = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ab229e32490>,
#   <matplotlib.lines.Line2D at 0x7ab229e33dd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ab229e32010>,
#   <matplotlib.lines.Line2D at 0x7ab229e327d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7ab22a309710>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ab229e32290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ab22a513010>],
#  'means': []}

# %%
plt.boxplot(mtcars['mpg'],vert = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ab22a2d1650>,
#   <matplotlib.lines.Line2D at 0x7ab22a2d12d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ab22a2d3c50>,
#   <matplotlib.lines.Line2D at 0x7ab22a2d0590>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7ab22a38e7d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ab22a2d1f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ab22a2d1950>],
#  'means': []}

# %%
plt.violinplot(mtcars["mpg"])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x7ab22ad22b90>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7ab22a372a90>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7ab22a5a49d0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7ab22a07c3d0>}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(y= 'tip',data=tips,jitter=True)
plt.ylabel('tip ($)')
plt.show()

# %%
sns.stripplot

# %%
sns.stripplot(x='day', y='tip', data=tips , size = 4,jitter = False)
plt.ylabel('tips($)')
plt.show()

# %%
sns.swarmplot(x='day',y = 'tip' , data =tips)
plt.ylabel('tip($)')
plt.show()

# %%
sns.swarmplot(x='day',y ='tip',data = tips,hue='sex')
plt.ylabel('tip($)')
plt.show()

# %%
sns.boxplot(x='day',y='tip',data =tips)
plt.ylabel('tip ($)')
# Out:
# Text(0, 0.5, 'tip ($)')

# %%
sns.violinplot(x="day", y='tip', data=tips)
plt.ylabel('tip ($)')
plt.show()

# %%
plt.subplot(1,2,1)
sns.boxplot(x='day',y="tip",data=tips)
plt.ylabel('tip ($)')
plt.show()

# %%
sns.violinplot(x='day',y='tip',data=tips, inner =None,color = 'lightgray')
sns.stripplot(x='day', y='tip',data=tips,size = 4,jitter =True)
plt.ylabel('tip($)')
plt.show()

# %%
sns.jointplot(x= 'total_bill', y= 'tip', data=tips)
plt.show()

# %%
sns.jointplot(x='total_bill', y='tip', data=tips,kind ='kde')
plt.show()

# %%
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips,hue='sex')
plt.show()
